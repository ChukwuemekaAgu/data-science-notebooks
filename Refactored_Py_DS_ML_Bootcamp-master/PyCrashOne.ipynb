# %%
1 + 1
# Out:
# 2

# %%
2 ** 4
# Out:
# 16

# %%
2 + 3 * 5 + 5
# Out:
# 22

# %% [markdown]
# 8 % 2

# %%
8 % 2
# Out:
# 0

# %%
# Strings

# %%
num = 12
name = 'Sam'

# %%
print('My number is {} and my name is {}'.format(num,name))
# Out:
# My number is 12 and my name is Sam
