# %%
d = {'k1':'test'}

# %%
d['k1']
# Out:
# 'test'

# %%
1 == 1
# Out:
# True

# %%
if 1<2:
    print('yep!')
# Out:
# yep!

# %%
if 1 == 2:
    print('First')
else:
    print('Last')
# Out:
# Last
