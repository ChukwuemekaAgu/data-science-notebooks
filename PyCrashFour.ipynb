# %%
def times2(var):
    return var*2

# %%
times2(5)
# Out:
# 10

# %%
seq = [1,2,3,4,5]

# %%
list(map(times,seq))
# Out:
# [2, 4, 6, 8, 10]

# %%
s = 'hello my name is Chuks'

# %%
s.lower()
# Out:
# 'hello my name is chuks'

# %%
s.upper()
# Out:
# 'HELLO MY NAME IS CHUKS'

# %%
s.split()
# Out:
# ['hello', 'my', 'name', 'is', 'Chuks']

# %%
'x' in ['x','y','z']
# Out:
# True
